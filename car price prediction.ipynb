# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
cars= pd.read_csv('car data.csv')
cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %% [markdown]
# # Describe

# %%
cars.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# # info

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# # Unique

# %%
print(cars['Selling_type'].unique())
print(cars['Fuel_Type'].unique())
print(cars['Transmission'].unique())
print(cars['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %% [markdown]
# # Columns

# %%
cars.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# # Corr

# %%
carscorr=cars[['Year', 'Present_Price', 'Driven_kms', 'Owner']]
carscorr.corr()
# Out:
#                    Year  Present_Price  Driven_kms     Owner
# Year           1.000000      -0.047192   -0.524342 -0.182104
# Present_Price -0.047192       1.000000    0.203618  0.008058
# Driven_kms    -0.524342       0.203618    1.000000  0.089216
# Owner         -0.182104       0.008058    0.089216  1.000000

# %% [markdown]
# # Checking for missing values

# %%
missing_count = cars.isna().sum()

print(missing_count)
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# # Find the five percent threshold

# %%
threshold = len(cars) * 0.05
threshold
# Out:
# 15.05

# %% [markdown]
# # Check the values of the Transmission column

# %%
print(cars["Transmission"].value_counts())
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %% [markdown]
# #  Check the values of the Fuel Type column

# %%
print(cars["Fuel_Type"].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %% [markdown]
# #  Check the values of the Selling Type column

# %%
print(cars["Selling_type"].value_counts())
# Out:
# Selling_type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %% [markdown]
# # Calculate the mean, median, and mode of the "Selling_Price" column

# %%
mean_price = cars['Selling_Price'].mean()
median_price = cars['Selling_Price'].median()
mode_price =cars['Selling_Price'].mode()

print(f"Mean Selling Price: {mean_price}")
print(f"Median Selling Price: {median_price}")
print(f"Mode Selling Price: {mode_price[0]}")
# Out:
# Mean Selling Price: 4.661295681063123
# Median Selling Price: 3.6
# Mode Selling Price: 0.45

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(cars)
# Out:
# c:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #  Create a dis plot of Year by Selling Price

# %%
sns.displot(data=cars, x="Year", y="Selling_Price")


plt.show()
# Out:
# c:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Calculate median Selling prices by Car Names

# %%
cars_prices = cars.groupby("Car_Name")["Selling_Price"].median()


print(cars_prices)
# Out:
# Car_Name
# 800                  0.350
# Activa 3g            0.310
# Activa 4g            0.400
# Bajaj  ct 100        0.180
# Bajaj Avenger 150    0.750
#                      ...
# sx4                  2.800
# verna                5.650
# vitara brezza        9.250
# wagon r              2.875
# xcent                4.750
# Name: Selling_Price, Length: 98, dtype: float64

# %% [markdown]
# # Calculate median Selling prices by Car Names through displot visualization

# %%
sns.displot(cars_prices)
# Out:
# c:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Plot the counts of each Selling Type

# %%
sns.countplot(data=cars, x="Selling_type")
plt.title('Plot the counts of each Selling Type')
plt.show()

# %% [markdown]
# # Plot the counts of each Fuel Type

# %%
sns.countplot(data=cars, x="Fuel_Type")
plt.title('Plot the counts of each Fuel Type')
plt.show()

# %% [markdown]
# # Plot the counts of each Transmission Type

# %%
sns.countplot(data=cars, x="Transmission")
plt.title('Plot the counts of each Transmission Type')
plt.show()

# %% [markdown]
# # Plot a histogram of Selling Price

# %%
sns.histplot(data=cars,x="Selling_Price", bins=20)  
plt.title('plot a histogram of Selling Price')
plt.show()

# %% [markdown]
# # Plot a histogram of Present Price

# %%
sns.histplot(data=cars,x="Present_Price", bins=20)  
plt.title('plot a histogram of Present Price')
plt.show()

# %% [markdown]
# # Calculate the standard deviation of Price by Cars

# %%
cars_price_st_dev =cars.groupby("Car_Name")["Selling_Price"].std()
cars["cars_price_st_dev"] = cars["Car_Name"].map(cars_price_st_dev)
print(cars[["Car_Name", "cars_price_st_dev"]].value_counts())
# Out:
# Car_Name                   cars_price_st_dev
# city                       2.620974             26
# corolla altis              4.234512             16
# verna                      1.621946             14
# fortuner                   6.904703             11
# brio                       0.909960             10
# i20                        1.711724              9
# ciaz                       0.577771              9
# innova                     8.054934              9
# grand i10                  0.538143              8
# Royal Enfield Classic 350  0.109065              7
# amaze                      0.726210              7
# jazz                       1.668796              7
# ertiga                     0.909258              6
# eon                        0.508920              6
# sx4                        1.154304              6
# i10                        0.567230              5
# swift                      1.098522              5
# ...

# %% [markdown]
# # Create a line plot showing the average number of Present Price by year

# %%
sns.lineplot(data=cars, x="Year", y="Present_Price")
plt.title("Average Number of Present Price by Year")
plt.show()

# %% [markdown]
# # Create a line plot showing the average number of Selling Price by year

# %%
sns.lineplot(data=cars, x="Year", y="Selling_Price")
plt.title("Average Number of Selling Price by Year")
plt.show()

# %% [markdown]
# # Create a bar plot showing the Average Number of Selling Price by Transmission

# %%
sns.barplot(data=cars, x="Transmission", y="Selling_Price")
plt.title("Average Number of Selling Price by Transmission")
plt.show()

# %% [markdown]
# # Create a bar plot showing the Average Number of Selling Price by Fuel Type

# %%
sns.barplot(data=cars, x="Fuel_Type", y="Selling_Price")
plt.title("Average Number of Selling Price by Fuel Type")
plt.show()

# %% [markdown]
# # Create a bar plot showing the Average Number of Selling Price by Selling Type

# %%
sns.barplot(data=cars, x="Selling_type", y="Selling_Price")
plt.title("Average Number of Selling Price by Selling Type")
plt.show()

# %% [markdown]
# # Slicing Data

# %%
x=cars[['Year', 'Present_Price', 'Driven_kms']]
y=cars['Selling_Price']

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Create and train a linear regression model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# # Coefficients

# %%
coefficients = model.coef_
coefficients
# Out:
# array([ 4.63574866e-01,  5.07465844e-01, -8.80866322e-07])

# %% [markdown]
# # Scatterplot with Regression Line

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Selling Price")
plt.ylabel("Predicted Selling Price")

sns.regplot(x=y_test, y=y_pred, line_kws={"color": "red"})
plt.show()

# %% [markdown]
# # Make predictions on the test set

# %%
y_pred = model.predict(X_test)
model.predict([[2014,6.87,42450]])
# Out:
# c:\Users\Hp\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.33910625])

# %% [markdown]
# # Calculate the Mean Squared Error to evaluate the Linear Regression performance

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}" )
# Out:
# Mean Squared Error: 2.8464835663646606

# %% [markdown]
# # Calculate the Mean Absolute Error to evaluate the Linear Regression performance

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 1.2086770190209546

# %% [markdown]
# # Calculate the R-squared (R2) Score to evaluate the Linear Regression performance

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f'R-squared (R2) Score: {r2*100}')
# Out:
# R-squared (R2) Score: 88.7389813185652

# %% [markdown]
# # Create a bar plot for MSE vs. MAE vs. R2

# %%
metrics = ['MSE', 'MAE','R2']
values = [mse, mae,r2]

plt.bar(metrics, values, color=['blue', 'green','red'])
plt.xlabel('Metrics')
plt.ylabel('Error Values')
plt.title('MSE vs. MAE vs. R2')
plt.show()
